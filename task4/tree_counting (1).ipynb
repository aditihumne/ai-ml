# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/My Drive/Tree_Counting

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/Tree_Counting
# Out:
# /content/drive/MyDrive/Tree_Counting

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=224 plots=True
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml					    P_curve.png       train_batch210.jpg
# confusion_matrix_normalized.png			    PR_curve.png      train_batch211.jpg
# confusion_matrix.png				    R_curve.png       train_batch212.jpg
# events.out.tfevents.1708161627.f9c72dc9e12a.1940.0  results.csv       train_batch2.jpg
# F1_curve.png					    results.png       val_batch0_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg  val_batch0_pred.jpg
# labels.jpg					    train_batch1.jpg  weights

# %%
Image(filename='/content/drive/MyDrive/Tree_Counting/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/Tree_Counting/runs/detect/train/results.png', width=600)

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Tree_Counting/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/Tree_Counting/test/images
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/27 /content/drive/MyDrive/Tree_Counting/test/images/cd_261945_4_174267_4_19_jpg.rf.9dab2691f2b32079ea1acf22d09db856.jpg: 224x224 55 trees, 109.4ms
# image 2/27 /content/drive/MyDrive/Tree_Counting/test/images/cd_261945_4_174267_4_19_jpg.rf.ddb144d0585868511cfda08f217c77ed.jpg: 224x224 55 trees, 110.3ms
# image 3/27 /content/drive/MyDrive/Tree_Counting/test/images/cd_261945_4_174267_4_19_jpg.rf.e22abc54501b74c5e684865c070c66a7.jpg: 224x224 55 trees, 103.0ms
# image 4/27 /content/drive/MyDrive/Tree_Counting/test/images/cl_261906_4_174459_4_19_jpg.rf.0cfe98c62536eb7515ca5c4fc614f1a3.jpg: 224x224 81 trees, 101.1ms
# image 5/27 /content/drive/MyDrive/Tree_Counting/test/images/cl_261906_4_174459_4_19_jpg.rf.210f889671c4d9f9d88846c7adf6f006.jpg: 224x224 81 trees, 119.2ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/drive/MyDrive/Tree_Counting/runs/detect/predict4/*4.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
